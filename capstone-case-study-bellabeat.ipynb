# %% [markdown]
# <a href="https://www.kaggle.com/code/shubhamgupta012/capstone-case-study-bellabeat?scriptVersionId=127691241" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteCaloriesNarrow_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyIntensities_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteIntensitiesWide_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteMETsNarrow_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyCalories_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyCalories_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/heartrate_seconds_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteSleep_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyIntensities_merged.csv
# /kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv
# ...

# %% [markdown]
# <h1>Importing DataSet</h1>

# %%
Calorie = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteCaloriesNarrow_merged.csv')
WeightLog = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv')
SleepDay = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv')
DailyIntensity = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyIntensities_merged.csv')
MinuteIntensity = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteIntensitiesWide_merged.csv')
MinuteMETsNarrow = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteMETsNarrow_merged.csv')
DailyCalories = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyCalories_merged.csv')
HourlyCalories = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyCalories_merged.csv')
Heartrate = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/heartrate_seconds_merged.csv')
MinuteSleep = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteSleep_merged.csv')
HourlyIntensities = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyIntensities_merged.csv')
HourlySteps = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv')
MinuteSteps = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteStepsNarrow_merged.csv')
DailySteps = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailySteps_merged.csv')
MinuteStepsWide = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteStepsWide_merged.csv')
MinuteIntensities = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteIntensitiesNarrow_merged.csv')
MinuteCalories = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/minuteCaloriesWide_merged.csv')
DailyActivity = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')

# %% [markdown]
# <h1>Inspecting Data</h1>

# %% [markdown]
# We are here going to view each data and inspect it whether we need to keep the data or drop it and how to analyze this data and what we should do so that we can move forward.

# %% [markdown]
# <h2>DataSet 1 : Minutes Calorie Narrow </h2>

# %%
Calorie.head()
# Out:
#            Id         ActivityMinute  Calories
# 0  1503960366  4/12/2016 12:00:00 AM    0.7865
# 1  1503960366  4/12/2016 12:01:00 AM    0.7865
# 2  1503960366  4/12/2016 12:02:00 AM    0.7865
# 3  1503960366  4/12/2016 12:03:00 AM    0.7865
# 4  1503960366  4/12/2016 12:04:00 AM    0.7865

# %%
Calorie.shape
# Out:
# (1325580, 3)

# %%
Calorie.describe()
# Out:
#                  Id      Calories
# count  1.325580e+06  1.325580e+06
# mean   4.847898e+09  1.623130e+00
# std    2.422313e+09  1.410447e+00
# min    1.503960e+09  0.000000e+00
# 25%    2.320127e+09  9.357000e-01
# 50%    4.445115e+09  1.217600e+00
# 75%    6.962181e+09  1.432700e+00
# max    8.877689e+09  1.974995e+01

# %%
Calorie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1325580 entries, 0 to 1325579
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1325580 non-null  int64
#  1   ActivityMinute  1325580 non-null  object
#  2   Calories        1325580 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.3+ MB

# %% [markdown]
# Checking Null values

# %%
Calorie.isnull().sum()
# Out:
# Id                0
# ActivityMinute    0
# Calories          0
# dtype: int64

# %% [markdown]
# Checking Duplicate Values

# %%
Calorie.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Here we check the unique Id in data by using unique() function . We found 33 unique Id .

# %%
Calorie['Id'].unique().shape
# Out:
# (33,)

# %%
import matplotlib.pyplot as plt
plt.hist(Calorie['Id'],bins=10)
# Out:
# (array([305940., 113100.,  28320., 222480.,  88020.,  86280.,  79500.,
#         160560.,  44100., 197280.]),
#  array([1.50396037e+09, 2.24133327e+09, 2.97870617e+09, 3.71607907e+09,
#         4.45345198e+09, 5.19082488e+09, 5.92819778e+09, 6.66557068e+09,
#         7.40294359e+09, 8.14031649e+09, 8.87768939e+09]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.boxplot(Calorie['Calories'])
# Out:
# <AxesSubplot:>

# %%
Calorie['Calories'].mean(),Calorie['Calories'].min(),Calorie['Calories'].max()
# Out:
# (1.6231295126578806, 0.0, 19.7499465942383)

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(Calorie)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# <h2>DataSet 2: WeightLog </h2>

# %%
WeightLog.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
WeightLog.shape
# Out:
# (67, 8)

# %%
WeightLog['Id'].unique()
# Out:
# array([1503960366, 1927972279, 2873212765, 4319703577, 4558609924,
#        5577150313, 6962181067, 8877689391])

# %%
DailyActivity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
uniqueId = Calorie['Id'].unique()
uniqueId.shape
# Out:
# (33,)

# %%
WeightLog.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
WeightLog['Id'].unique()
# Out:
# array([1503960366, 1927972279, 2873212765, 4319703577, 4558609924,
#        5577150313, 6962181067, 8877689391])

# %%
Calorie.shape,WeightLog.shape
# Out:
# ((1325580, 3), (67, 8))
