# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamGupta2505/MachineLearningPractice/blob/main/ADS_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('titanic (1).csv')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Univariate Analysis

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
Y = df['survived']
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %% [markdown]
# # Handling Missing Values

# %%
median_age = df['age'].median()
median_age
# Out:
# 28.0

# %%
df['age'].fillna(value=median_age,inplace=True)

# %%
df['deck'].fillna(value='null',inplace=True)

# %%
df['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df['embarked'].fillna(value='S',inplace=True)

# %%
df['embark_town'].fillna(value='Southampton',inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
import seaborn as sns

# %%
plt.scatter(df.index,df['fare'])
plt.show()

# %%
plt.scatter(df.index,df['age'])
plt.show()

# %%
plt.scatter(df.index,df['fare'])
plt.show()

# %%
plt.hist(df['age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Multi-Variate Analysis

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, cbar=True, fmt='.2f', annot=True, annot_kws={'size':15}, cmap='Greens')
# Out:
# <Axes: >

# %%
df.hist(bins=50, figsize=(16,14))
plt.show()

# %% [markdown]
# # Outliers

# %%
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0931ffd420>,
#   <matplotlib.lines.Line2D at 0x7f0931ffd6c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0931ffd960>,
#   <matplotlib.lines.Line2D at 0x7f0931ffdc00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0931ffd180>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0931ffdea0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0931ffe140>],
#  'means': []}

# %%
plt.boxplot(df['fare']
            )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0932075a50>,
#   <matplotlib.lines.Line2D at 0x7f0932075cf0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0932075f90>,
#   <matplotlib.lines.Line2D at 0x7f0932076230>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f09320740a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f09320764d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0932076770>],
#  'means': []}

# %%
upper = df['age'].mean() + 3*df['age'].std()
lower = df['age'].mean() - 3*df['age'].std()

# %%
lower,upper
# Out:
# (-9.697507161337114, 68.42067214450209)

# %%
df['age'] = np.where(df['age']>upper,upper,np.where(df['age']<lower,lower,df['age']))

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.330656    0.523008    0.381594   32.204208
# std      0.486592    0.836071   12.918277    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   68.420672    8.000000    6.000000  512.329200

# %%
upper1 = df['fare'].mean() + 3*df['fare'].std()
lower1 = df['fare'].mean() - 3*df['fare'].std()

# %%
upper1,lower1
# Out:
# (181.2844937601173, -116.87607782296804)

# %%
df['fare'] = np.where(df['fare']>upper1,upper1,np.where(df['fare']<lower1,lower1,df['fare']))

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.330656    0.523008    0.381594   30.003893
# std      0.486592    0.836071   12.918277    1.102743    0.806057   36.989591
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   68.420672    8.000000    6.000000  181.284494

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['sex'] = le.fit_transform(df['sex'])
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male  deck  embark_town alive  alone
# 0        True  null  Southampton    no  False
# 1       False     C    Cherbourg   yes  False
# 2       False  null  Southampton   yes   True
# 3       False     C  Southampton   yes  False
# 4        True  null  Southampton    no   True

# %%
df['embarked'] = le.fit_transform(df['embarked'])
df['class'] = le.fit_transform(df['class'])
df['who'] = le.fit_transform(df['who'])
df['adult_male'] = le.fit_transform(df['adult_male'])
df['deck'] = le.fit_transform(df['deck'])
df['embark_town'] = le.fit_transform(df['embark_town'])

# %%
df['alive'] = le.fit_transform(df['alive'])
df['alone'] = le.fit_transform(df['alone'])

# %%
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500         2      2    1
# 1         1       1    0  38.0      1      0  71.2833         0      0    2
# 2         1       3    0  26.0      0      0   7.9250         2      2    2
# 3         1       1    0  35.0      1      0  53.1000         2      0    2
# 4         0       3    1  35.0      0      0   8.0500         2      2    1
#
#    adult_male  deck  embark_town  alive  alone
# 0           1     7            2      0      0
# 1           0     2            0      1      0
# 2           0     7            2      1      1
# 3           0     2            2      1      0
# 4           1     7            2      0      1

# %%
df.describe()
# Out:
#          survived      pclass         sex         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.330656    0.523008    0.381594
# std      0.486592    0.836071    0.477990   12.918277    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   68.420672    8.000000    6.000000
#
#              fare    embarked       class         who  adult_male        deck  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    30.003893    1.536476    1.308642    1.210999    0.602694    5.945006
# std     36.989591    0.791503    0.836071    0.594291    0.489615    2.061500
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      7.910400    1.000000    1.000000    1.000000    0.000000    7.000000
# 50%     14.454200    2.000000    2.000000    1.000000    1.000000    7.000000
# 75%     31.000000    2.000000    2.000000    2.000000    1.000000    7.000000
# max    181.284494    2.000000    2.000000    2.000000    1.000000    7.000000
#
#        embark_town       alive       alone
# count   891.000000  891.000000  891.000000
# mean      1.536476    0.383838    0.602694
# std       0.791503    0.486592    0.489615
# min       0.000000    0.000000    0.000000
# 25%       1.000000    0.000000    0.000000
# 50%       2.000000    0.000000    1.000000
# 75%       2.000000    1.000000    1.000000
# max       2.000000    1.000000    1.000000

# %% [markdown]
# # Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(df,Y,test_size=0.2,random_state=0)

# %%
X_train.shape,Y_train.shape
# Out:
# ((712, 15), (712,))

# %%
X_test.shape,Y_test.shape
# Out:
# ((179, 15), (179,))

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mns = MinMaxScaler()
X = pd.DataFrame(mns.fit_transform(df), columns=df.columns)

# %%
X.describe()
# Out:
#          survived      pclass         sex         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    0.654321    0.647587    0.425153    0.065376    0.063599
# std      0.486592    0.418036    0.477990    0.189973    0.137843    0.134343
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.500000    0.000000    0.317350    0.000000    0.000000
# 50%      0.000000    1.000000    1.000000    0.405584    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.508524    0.125000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              fare    embarked       class         who  adult_male        deck  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.165507    0.768238    0.654321    0.605499    0.602694    0.849287
# std      0.204042    0.395752    0.418036    0.297146    0.489615    0.294500
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.043635    0.500000    0.500000    0.500000    0.000000    1.000000
# 50%      0.079732    1.000000    1.000000    0.500000    1.000000    1.000000
# 75%      0.171002    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        embark_town       alive       alone
# count   891.000000  891.000000  891.000000
# mean      0.768238    0.383838    0.602694
# std       0.395752    0.486592    0.489615
# min       0.000000    0.000000    0.000000
# 25%       0.500000    0.000000    0.000000
# 50%       1.000000    0.000000    1.000000
# 75%       1.000000    1.000000    1.000000
# max       1.000000    1.000000    1.000000
