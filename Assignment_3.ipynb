# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('Housing.csv')
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %% [markdown]
# # Descriptive Statistics

# %%
df.shape
# Out:
# (545, 12)

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# furnishingstatus    object
# dtype: object

# %% [markdown]
# # Checking missing and null values

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Univariate Analysis

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.scatter(df.index,df['furnishingstatus'])
plt.show()

# %%
plt.hist(df['furnishingstatus'])
# Out:
# (array([140.,   0.,   0.,   0.,   0., 227.,   0.,   0.,   0., 178.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['price'])
# Out:
# (array([ 61., 163., 139.,  89.,  46.,  25.,  13.,   4.,   1.,   4.]),
#  array([ 1750000.,  2905000.,  4060000.,  5215000.,  6370000.,  7525000.,
#          8680000.,  9835000., 10990000., 12145000., 13300000.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Bivariate Analysis

# %%
sns.barplot(x='guestroom',y='furnishingstatus',data=df)
# sns.countplot(x='guestroom',data=df)
# Out:
# <Axes: xlabel='guestroom', ylabel='furnishingstatus'>

# %%
sns.boxplot(x='bedrooms',y='price',data=df,palette='rainbow')
# sns.violinplot(x="day", y="total_bill", data=t,palette='rainbow')
# sns.stripplot(x="day", y="total_bill", data=t)
# sns.swarmplot(x="day", y="total_bill", data=t)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.violinplot(x="bedrooms", y="price", data=df,palette='rainbow')
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.stripplot(x="bedrooms", y="price", data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.swarmplot(x="bedrooms", y="price", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 19.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 30.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='bedrooms', ylabel='price'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 23.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 34.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='bathrooms',y='price',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
sns.violinplot(x="bathrooms", y="price", data=df,palette='rainbow')
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
sns.stripplot(x="bathrooms", y="price", data=df)
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
sns.swarmplot(x="bathrooms", y="price", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 29.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='bathrooms', ylabel='price'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='stories',y='price',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='stories', ylabel='price'>

# %%
sns.violinplot(x="stories", y="price", data=df,palette='rainbow')
# Out:
# <Axes: xlabel='stories', ylabel='price'>

# %%
sns.stripplot(x="stories", y="price", data=df)
# Out:
# <Axes: xlabel='stories', ylabel='price'>

# %%
sns.swarmplot(x="stories", y="price", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 7.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 7.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='stories', ylabel='price'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 12.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Multi-Variate Analysis

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, cbar=True, fmt='.2f', annot=True, annot_kws={'size':15}, cmap='Greens')
# Out:
# <Axes: >

# %%
df.hist(bins=50, figsize=(16,14))
plt.show()

# %%
pd.plotting.scatter_matrix(df.loc[:, "price":"furnishingstatus"], diagonal="kde",figsize=(20,15))
plt.show()

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['mainroad'] = le.fit_transform(df['mainroad'])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 0  13300000  7420         4          2        3         1        no       no
# 1  12250000  8960         4          4        4         1        no       no
# 2  12250000  9960         3          2        2         1        no      yes
# 3  12215000  7500         4          2        2         1        no      yes
# 4  11410000  7420         4          1        2         1       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
df['guestroom'] = le.fit_transform(df['guestroom'])
df['basement'] = le.fit_transform(df['basement'])
df['hotwaterheating'] = le.fit_transform(df['hotwaterheating'])
df['airconditioning'] = le.fit_transform(df['airconditioning'])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking furnishingstatus
# 0         0                0                1        2        furnished
# 1         0                0                1        3        furnished
# 2         1                0                0        2   semi-furnished
# 3         1                0                1        3        furnished
# 4         1                0                1        2        furnished

# %%
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
df['furnishingstatus'].value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
df['furnishingstatus'] = le.fit_transform(df['furnishingstatus'])
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 0         0                0                1        2                 0
# 1         0                0                1        3                 0
# 2         1                0                0        2                 1
# 3         1                0                1        3                 0
# 4         1                0                1        2                 0

# %% [markdown]
# # Splitting Dependent and Independent Variables

# %%
Y = df['furnishingstatus']
Y
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 540    2
# 541    1
# 542    2
# 543    0
# 544    2
# Name: furnishingstatus, Length: 545, dtype: int64

# %%
X = df.drop(['furnishingstatus'],axis=1)

# %%
X.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking
# 0         0                0                1        2
# 1         0                0                1        3
# 2         1                0                0        2
# 3         1                0                1        3
# 4         1                0                1        2

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mns = MinMaxScaler()
X = pd.DataFrame(mns.fit_transform(X), columns=X.columns)

# %%
X.head()
# Out:
#       price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 0  1.000000  0.396564       0.6   0.333333  0.666667       1.0        0.0
# 1  0.909091  0.502405       0.6   1.000000  1.000000       1.0        0.0
# 2  0.909091  0.571134       0.4   0.333333  0.333333       1.0        0.0
# 3  0.906061  0.402062       0.6   0.333333  0.333333       1.0        0.0
# 4  0.836364  0.396564       0.6   0.000000  0.333333       1.0        1.0
#
#    basement  hotwaterheating  airconditioning   parking  furnishingstatus
# 0       0.0              0.0              1.0  0.666667               0.0
# 1       0.0              0.0              1.0  1.000000               0.0
# 2       1.0              0.0              0.0  0.666667               0.5
# 3       1.0              0.0              1.0  1.000000               0.0
# 4       1.0              0.0              1.0  0.666667               0.0

# %% [markdown]
# # Splitting Dataset into Training and Testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train.shape,Y_train.shape
# Out:
# ((436, 12), (436,))

# %%
X_test.shape,Y_test.shape
# Out:
# ((109, 12), (109,))

# %% [markdown]
# # Building Model

# %% [markdown]
# ## SVM

# %%
from sklearn import svm
svm = svm.SVC(kernel='linear', C=1.0)

# %%
svm.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(Y_test,y_pred)
acc
# Out:
# 1.0

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
y_pred=gbc.predict(X_test)

print(accuracy_score(Y_test,y_pred))
# Out:
# 1.0

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
y_pred=rf.predict(X_test)

print(accuracy_score(Y_test,y_pred))
# Out:
# 1.0

# %% [markdown]
# ## KNeighboursClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier()
k.fit(X_train,Y_train)
result=k.predict(X_test)
print(accuracy_score(Y_test,result))
# Out:
# 0.926605504587156
