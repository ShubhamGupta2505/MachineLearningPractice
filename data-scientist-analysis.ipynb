# %% [markdown]
# <a href="https://www.kaggle.com/code/shubhamgupta012/data-scientist-analysis?scriptVersionId=133940845" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/data-scientist-salaries-8000-companies/Data_Companies_Salaries1.csv

# %%
df = pd.read_csv('/kaggle/input/data-scientist-salaries-8000-companies/Data_Companies_Salaries1.csv')
df.head()
# Out:
#                 Company Name  Rating Average Salary            Role
# 0  Tata Consultancy Services     3.9       7,80,000  Data Scientist
# 1                        IBM     4.0      12,00,000  Data Scientist
# 2                  Accenture     4.0      10,51,857  Data Scientist
# 3                   Mu Sigma     3.5       7,25,000  Data Scientist
# 4                    Infosys     3.3       7,70,714  Data Scientist

# %%
df.sample(30)
# Out:
#                          Company Name  Rating Average Salary  \
# 292                        Freshworks     3.9       8,71,506
# 6090                         Experian     4.2        9L -10L
# 1184                      HackerEarth     3.9         1L -2L
# 2436                          Telstra     3.9       20L -22L
# 6272                              1mg     3.7       22L -24L
# 3804                  Ahaka Solutions     4.6         8L -9L
# 1944                       Merilytics     3.7        9L -10L
# 7048                    iD Tech Camps     4.1       17T -18T
# 2298            Netcracker Technology     3.8       18L -19L
# 5151                       Concentrix     4.1       33T -41T
# 7878                      ACR Systems     3.6       40T -43T
# 7035                       HighRadius     3.7       14T -15T
# 4225                    Berger Paints     3.5       25T -28T
# 5451                  NewAge Products     4.1         9L -9L
# ...

# %%
df['Average Salary'] = df['Average Salary'].str.replace('[^\d]', '', regex=True).astype(int)

# %%
df.shape
# Out:
# (8431, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8431 entries, 0 to 8430
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company Name    8430 non-null   object
#  1   Rating          8249 non-null   float64
#  2   Average Salary  8431 non-null   int64
#  3   Role            8431 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 263.6+ KB

# %%
df.dtypes
# Out:
# Company Name       object
# Rating            float64
# Average Salary      int64
# Role               object
# dtype: object

# %%
df['Company Name'].value_counts()
# Out:
# Tata Consultancy Services                          34
# Accenture                                          32
# IBM                                                25
# Deloitte                                           23
# Infosys                                            23
#                                                    ..
# Nothing Bundt Cakes                                 1
# Intellicar                                          1
# Talent Zone Consultants                             1
# All India Institute of Medical Sciences (India)     1
# Vaer Solutions                                      1
# Name: Company Name, Length: 5059, dtype: int64

# %%
df['Role'].value_counts()
# Out:
# Data Scientist                                3086
# Data Scientist - Monthly                       740
# Senior Data Scientist                          717
# Data Science - Monthly Intern                  530
# Data Scientist - Monthly Intern                323
#                                               ...
# Research Data Scientist - Monthly Intern         1
# Data Scientist/Software Engineer - Monthly       1
# Data Scientist Consultant - Monthly Intern       1
# Data Scientist Consultant - Monthly              1
# Data Scientist Lead - Monthly                    1
# Name: Role, Length: 188, dtype: int64

# %%
df['Role'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Role'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Rating'}>,
#         <Axes: title={'center': 'Average Salary'}>]], dtype=object)

# %% [markdown]
# # Not much to do in this Dataset
